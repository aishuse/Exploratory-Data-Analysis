# %% [markdown]
# <a href="https://colab.research.google.com/github/aishuse/Exploratory-Data-Analysis/blob/master/Sales_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/Datasets/supermarket_sales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Uni-variate analysis**

# %% [markdown]
# ## What does the customer rating look like and is it skewed?

# %%
sns.distplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %% [markdown]
# * The rating distribution looks uniform and there seems to be no skewness on the left or right side of the distribution.

# %% [markdown]
# # Is there any difference in aggregate sales across branches?

# %%
ax = sns.countplot(df['Branch'])
for i in ax.containers:
  ax.bar_label(i)

# %%
df['Branch'].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %% [markdown]
# *The sales in branch A is a bit higher than the rest of the branches.

# %% [markdown]
# # Which is the most popular payment method used by customers?

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
ax = sns.countplot(df['Payment'])
for i in ax.containers:
  ax.bar_label(i)

# %% [markdown]
# *The most popular payment method is in-fact E-wallet and not credit cards.Cash payment is also popular.

# %% [markdown]
# ## **Bi-variate analysis**

# %% [markdown]
# # Does gross income affect the ratings that the customers provide?

# %%
sns.pairplot(df)

# %%
sns.scatterplot(data=df, x='Rating', y='gross income')
# Out:
# <Axes: xlabel='Rating', ylabel='gross income'>

# %% [markdown]
# *There is no relationship between gross income of a customer and his rating.

# %% [markdown]
# # Which branch is the most profitable?

# %%
sns.boxplot(data=df, x='Branch', y='gross income')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(data=df, x='Branch', y='gross income')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
#  *Branch C has a slightly higher income than A or B

# %% [markdown]
# # Is there any relationship between Gender and Gross income?

# %%
sns.boxplot(data=df, x='Gender', y='gross income')
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
ax = sns.barplot(data=df, x='Gender', y='gross income')
for i in ax.containers:
  ax.bar_label(i)

# %% [markdown]
# * female customers spend a bit higher

# %% [markdown]
# # Is there any time trend in gross income?

# %%
sns.boxplot(data=df, x='Date', y='gross income')
# Out:
# <Axes: xlabel='Date', ylabel='gross income'>

# %%
# Convert 'Date' column to datetime if it's not already in datetime format
df['Date'] = pd.to_datetime(df['Date'])
plt.figure(figsize=(8,8))

sns.lineplot(data=df, x='Date', y='gross income')
# Out:
# <Axes: xlabel='Date', ylabel='gross income'>

# %% [markdown]
# # Which product line generates most income?

# %%
df1 = pd.read_csv('/content/gdrive/MyDrive/Colab_Notebooks/Datasets/supermarket_sales.csv')

# %%
df1.drop(['Date'],axis = 1, inplace=True)
df1
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total   Time  \
# 0         Health and beauty       74.69         7  26.1415   548.9715  13:08
# 1    Electronic accessories       15.28         5   3.8200    80.2200  10:29
# ...

# %%
cat = df1.groupby(['Product line'], as_index=False).sum()
plt.figure(figsize=(12,8))
ax = sns.barplot(x='Product line', y='gross income', data=cat)
for i in ax.containers:
  ax.bar_label(i)

# %% [markdown]
# or

# %%
cat=df[["Product line", "gross income"]].groupby(['Product line'], as_index=False).sum().sort_values(by='gross income', ascending=False)
plt.figure(figsize=(12,8))
ax = sns.barplot(x='Product line', y='gross income', data=cat)
for i in ax.containers:
  ax.bar_label(i)

# %% [markdown]
# * Gross income is high in Food and beverages

# %% [markdown]
# # What is the spending pattern of females and males and in which category do they spend a lot?

# %%
plt.figure(figsize=(12, 6))
plt.title('Total Monthly transaction by Gender')

sns.countplot(data=df, x='Product line', hue='Gender')
# Out:
# <Axes: title={'center': 'Total Monthly transaction by Gender'}, xlabel='Product line', ylabel='count'>

# %% [markdown]
# *Females spend on 'fashion accessories' the most and for males it is 'Health and beauty'. Females also spend more on 'Sports and travel'.

# %% [markdown]
# # How many products are bought by customers?

# %%
sns.distplot(df['Quantity'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Density'>

# %% [markdown]
#  *Most of the customers buy 10 quantities.

# %% [markdown]
# # Which day of the week has maximum sales?

# %%
sns.countplot(df['Date'].dt.day_name())
# Out:
# <Axes: xlabel='count', ylabel='Date'>

# %% [markdown]
# *Sales is highest on Saturdays probably because it is the weekend. Interestingly,Tuesdays is a close second.Mondays is the lowest in sales

# %% [markdown]
# # Which hour of the day is the busiest?

# %%
df['Time'] = pd.to_datetime(df['Time'])   #column to datetime
df['Hour'] = (df['Time']).dt.hour
df['Hour'].unique()

sns.lineplot(x="Hour",  y = 'Quantity',data =df).set_title("Product Sales per Hour")
# Out:
# Text(0.5, 1.0, 'Product Sales per Hour')

# %% [markdown]
# *Peak is observed in the 14th hour i.e 2 pm of the day. Hence, sales is typically higher in the afternoons.

# %% [markdown]
# # Which product line should the supermarket focus on?

# %%
sns.boxenplot(y = 'Product line', x = 'Quantity', data=df )
# Out:
# <Axes: xlabel='Quantity', ylabel='Product line'>

# %%
sns.barplot(y = 'Product line', x = 'Quantity', data=df )
# Out:
# <Axes: xlabel='Quantity', ylabel='Product line'>

# %%
sns.barplot(y = df['Product line'], x = df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Product line'>

# %% [markdown]
# *Though the rating for ‘fashion accessories’ and ‘food and beverages’ is high but quantity purchased is low. Hence, supply for these products need to be increased.

# %% [markdown]
# # Which city should be chosen for expansion and which products should it focus on?

# %%
sns.countplot(y ='Product line', hue = "City", data = df)
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %%
sns.barplot(x=df['City'],y=df['gross income'],palette='Set1')
# Out:
# <Axes: xlabel='City', ylabel='gross income'>

# %% [markdown]
# *Fashion accessories and food and beverages are the most sold product in Naypyitaw and these products should be focused on for expansion along with electronic accessories.
